# %%
Balance =1000
user_pin={"Shruti":1267,"Pranjal":7621,"Komal":2345,"Monalisha":2687,"Riya":9657}
count = 0
while count < 3:
   name=str(input("Enter name:"))
   pin=int(input("Enter pin:"))
   if pin and name in user_pin :
        print("Login successfully")
        print("___MENU__")
        print("1.Deposite")
        print("2.Withdraw")
        print("3.Exit")
        choice=input("Enter choice:")
        if choice == "1":
           print("Deposite amount")
           amount=float(input("enter amount:"))
           Balance += amount
           print("Deposite successful")
           print("Balance=",Balance) 
        elif choice == "2":
           print("Withdraw")
           amount = float(input("Enter amount:"))
           Balance -= amount
           print("withdraw successful")
           print("Balance=",Balance)
        elif choice == "3":
           print("Exit")
           break
        else:
           print("Invalid choice")
           break
            
   else:
        print("Try again")
        count+= 1
else:
   print("System locked")
# Out:
# Enter name: Shruti
# Enter pin: 1267
# Login successfully
# ___MENU__
# 1.Deposite
# 2.Withdraw
# 3.Exit
# Enter choice: 3
# Exit
